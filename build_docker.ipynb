# %% [markdown]
# ## Docker Deployment for
# #### Pipeline segment: **Data Preprocessing**
# ---

# %%
# %%bash
#
# image=cutomer-churn-preprocessing-image
#
# cd preprocessing/
#
# # Get the account number associated with the current IAM credentials
# account=$(aws sts get-caller-identity --query Account --output text)
#
# if [ $? -ne 0 ]
# then
#     exit 255
# fi
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# #region=${region:-us-west-1}
#
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image}:latest"
#
# # If the repository doesn't exist in ECR, create it.
#
# aws ecr describe-repositories --repository-names "${image}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${image}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# aws ecr get-login-password --region "${region}" | docker login --username AWS --password-stdin "${account}".dkr.ecr."${region}".amazonaws.com
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
#
# docker build  -t ${image} .
# docker tag ${image} ${fullname}
#
# docker push ${fullname}
# Out:
# Login Succeeded
# Sending build context to Docker daemon  8.704kB
# Step 1/13 : FROM ubuntu:20.04
#  ---> d13c942271d6
# Step 2/13 : ENV LANG=C.UTF-8 LC_ALL=C.UTF-8
#  ---> Using cache
#  ---> f123aae0ff55
# Step 3/13 : RUN apt-get update --fix-missing && apt-get install -y wget bzip2 ca-certificates     libglib2.0-0 libxext6 libsm6 libxrender1
#  ---> Using cache
#  ---> df6ade93f821
# Step 4/13 : RUN apt-get update && apt-get install -y --no-install-recommends      python3      python3-pip      &&      apt-get clean &&      rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> 6446516d3f27
# Step 5/13 : ARG PIP=pip3
#  ---> Using cache
#  ---> d6e2f0ddbeb2
# Step 6/13 : WORKDIR /
#  ---> Using cache
#  ---> 973538b0528e
# Step 7/13 : RUN pip3 install pandas
#  ---> Using cache
#  ---> 87d6d843a553
# Step 8/13 : RUN pip3 install sklearn
#  ---> Using cache
#  ---> 069f19ab1034
# Step 9/13 : RUN pip3 install boto3
#  ---> Running in dedce8ddb894
# Collecting boto3
#   Downloading boto3-1.20.46-py3-none-any.whl (131 kB)
# Collecting botocore<1.24.0,>=1.23.46
#   Downloading botocore-1.23.46-py3-none-any.whl (8.5 MB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore<1.24.0,>=1.23.46->boto3) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.24.0,>=1.23.46->boto3) (1.16.0)
# Installing collected packages: jmespath, urllib3, botocore, s3transfer, boto3
# Successfully installed boto3-1.20.46 botocore-1.23.46 jmespath-0.10.0 s3transfer-0.5.0 urllib3-1.26.8
# Removing intermediate container dedce8ddb894
#  ---> 328e49257a0b
# Step 10/13 : RUN pip install pyarrow
#  ---> Running in 3f5f4f7fba80
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from pyarrow) (1.22.1)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-6.0.1
# Removing intermediate container 3f5f4f7fba80
#  ---> 48fc86551468
# Step 11/13 : RUN pip install fastparquet
#  ---> Running in 1d1b90f9f358
# Collecting fastparquet
#   Downloading fastparquet-0.8.0-cp38-cp38-manylinux2010_x86_64.whl (1.6 MB)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.8/dist-packages (from fastparquet) (1.22.1)
# Collecting fsspec
#   Downloading fsspec-2022.1.0-py3-none-any.whl (133 kB)
# Collecting cramjam>=2.3.0
#   Downloading cramjam-2.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.6 MB)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from fastparquet) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.0->fastparquet) (2021.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.0->fastparquet) (1.16.0)
# Installing collected packages: fsspec, cramjam, fastparquet
# Successfully installed cramjam-2.5.0 fastparquet-0.8.0 fsspec-2022.1.0
# Removing intermediate container 1d1b90f9f358
#  ---> f948ba007a78
# Step 12/13 : ENV PYTHONUNBUFFERED=TRUE
#  ---> Running in 5982c222cdad
# Removing intermediate container 5982c222cdad
#  ---> e6a05c39d8ac
# Step 13/13 : ENTRYPOINT ["python3", "preprocessing.py"]
#  ---> Running in c9922b97c730
# Removing intermediate container c9922b97c730
#  ---> f608222c45f9
# Successfully built f608222c45f9
# Successfully tagged cutomer-churn-preprocessing-image:latest
# The push refers to repository [120582440665.dkr.ecr.ap-southeast-1.amazonaws.com/cutomer-churn-preprocessing-image]
# 5ec62c19c4d3: Preparing
# 1905e3de4f19: Preparing
# 59105e42dc62: Preparing
# 27613c0261e7: Preparing
# 4266e99295d9: Preparing
# 7e73b0dad4d0: Preparing
# 491a2ee5fddd: Preparing
# 0eba131dffd0: Preparing
# 7e73b0dad4d0: Waiting
# 491a2ee5fddd: Waiting
# 0eba131dffd0: Waiting
# 5ec62c19c4d3: Pushed
# 59105e42dc62: Pushed
# 1905e3de4f19: Pushed
# 7e73b0dad4d0: Pushed
# 491a2ee5fddd: Pushed
# 0eba131dffd0: Pushed
# 4266e99295d9: Pushed
# 27613c0261e7: Pushed
# latest: digest: sha256:4f850032df2e119c5e69b35c70418b52f28e9398143d6b8d003db080bc1b7991 size: 2013
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store

# %% [markdown]
# ## Docker Deployment for
# #### Pipeline segment: **Training**
# ---

# %%
# %%bash
#
# image=cutomer-churn-training-image
#
# cd training/
#
# chmod +x model/
#
# # Get the account number associated with the current IAM credentials
# account=$(aws sts get-caller-identity --query Account --output text)
#
# if [ $? -ne 0 ]
# then
#     exit 255
# fi
#
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-ap-southeast-1}
#
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image}:latest"
#
# # If the repository doesn't exist in ECR, create it.
#
# aws ecr describe-repositories --repository-names "${image}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${image}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# #aws ecr get-login-password --region "${region}" | docker login --username AWS --password-stdin "${account}".dkr.ecr."${region}".amazonaws.com
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
# aws ecr get-login-password --region "${region}" | docker login --username AWS --password-stdin "${account}".dkr.ecr."${region}".amazonaws.com
#
# docker build  -t ${image} ./
# docker tag ${image} ${fullname}
#
# docker push ${fullname}
# Out:
# Login Succeeded
# Sending build context to Docker daemon  15.87kB
# Step 1/12 : FROM ubuntu:20.04
#  ---> d13c942271d6
# Step 2/12 : ENV LANG=C.UTF-8 LC_ALL=C.UTF-8
#  ---> Using cache
#  ---> f123aae0ff55
# Step 3/12 : RUN apt-get update --fix-missing && apt-get install -y wget bzip2 ca-certificates     libglib2.0-0 libxext6 libsm6 libxrender1
#  ---> Using cache
#  ---> df6ade93f821
# Step 4/12 : RUN apt-get update && apt-get install -y --no-install-recommends      python3      python3-pip      python3-dev      &&      apt-get clean &&      rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> ca361276e8cc
# Step 5/12 : RUN apt-get update --fix-missing &&     apt-get -y install gcc g++ make
#  ---> Using cache
#  ---> 722ba9297b92
# Step 6/12 : ARG PIP=pip3
#  ---> Using cache
#  ---> 7ae7146f5253
# Step 7/12 : WORKDIR /
#  ---> Using cache
#  ---> cbb136f400bc
# Step 8/12 : RUN ${PIP} install --no-cache --upgrade             lightgbm             tqdm             xgboost             seaborn             sklearn             pyarrow             fastparquet
#  ---> Using cache
#  ---> 1ec6633a763e
# Step 9/12 : ENV PYTHONDONTWRITEBYTECODE=1     PYTHONUNBUFFERED=1     LD_LIBRARY_PATH="${LD_LIBRARY_PATH}:/usr/local/lib"     PYTHONIOENCODING=UTF-8     LANG=C.UTF-8     LC_ALL=C.UTF-8
#  ---> Using cache
#  ---> 019afc48f440
# Step 10/12 : RUN ${PIP} install --no-cache --upgrade     sagemaker-training
#  ---> Using cache
#  ---> 197784cf2f17
# Step 11/12 : COPY model/train.py /opt/ml/code/
#  ---> 82bcf2d5022f
# Step 12/12 : ENV SAGEMAKER_PROGRAM train.py
#  ---> Running in 31cf389bc2e2
# Removing intermediate container 31cf389bc2e2
#  ---> 01afec8e4c01
# Successfully built 01afec8e4c01
# Successfully tagged cutomer-churn-training-image:latest
# The push refers to repository [120582440665.dkr.ecr.ap-southeast-1.amazonaws.com/cutomer-churn-training-image]
# 34208ad685c5: Preparing
# 8fead02c8a66: Preparing
# fa84d4206d61: Preparing
# 365ac4a21fde: Preparing
# eefe3b7570bd: Preparing
# 491a2ee5fddd: Preparing
# 0eba131dffd0: Preparing
# 491a2ee5fddd: Waiting
# 0eba131dffd0: Waiting
# eefe3b7570bd: Layer already exists
# 365ac4a21fde: Layer already exists
# 8fead02c8a66: Layer already exists
# fa84d4206d61: Layer already exists
# 491a2ee5fddd: Layer already exists
# 0eba131dffd0: Layer already exists
# 34208ad685c5: Pushed
# latest: digest: sha256:39513c8106d41e19eee605aaed37ef83debdec370d93b6b71769eefc4c12be8c size: 1798
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store

# %% [markdown]
# ## Docker Deployment for
# #### Pipeline segment: **Inference : Batch Transformation**
# ---

# %%
# %%bash
#
# image=customer-churn-inference-image
#
# cd inferencing
#
# chmod +x model/
#
# # Get the account number associated with the current IAM credentials
# account=$(aws sts get-caller-identity --query Account --output text)
#
# if [ $? -ne 0 ]
# then
#     exit 255
# fi
#
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-ap-southeast-1}
#
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image}:latest"
#
# # If the repository doesn't exist in ECR, create it.
#
# aws ecr describe-repositories --repository-names "${image}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${image}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# #aws ecr get-login-password --region "${region}" | docker login --username AWS --password-stdin "${account}".dkr.ecr."${region}".amazonaws.com
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
# aws ecr get-login-password --region "${region}" | docker login --username AWS --password-stdin "${account}".dkr.ecr."${region}".amazonaws.com
#
# docker build  -t ${image} ./
# docker tag ${image} ${fullname}
#
# docker push ${fullname}
# Out:
# Login Succeeded
# Sending build context to Docker daemon  29.18kB
# Step 1/14 : FROM ubuntu:20.04
#  ---> d13c942271d6
# Step 2/14 : ENV LANG=C.UTF-8 LC_ALL=C.UTF-8
#  ---> Using cache
#  ---> f123aae0ff55
# Step 3/14 : RUN apt-get update --fix-missing && apt-get install -y wget bzip2 ca-certificates     libglib2.0-0 libxext6 libsm6 libxrender1
#  ---> Using cache
#  ---> df6ade93f821
# Step 4/14 : RUN apt-get update && apt-get install -y --no-install-recommends      python3      python3-pip      python3-dev      python3-setuptools      nginx      &&      apt-get clean &&      rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> f05ba083e9f9
# Step 5/14 : RUN apt-get update --fix-missing &&     apt-get -y install gcc g++ make
#  ---> Using cache
#  ---> 2ac019d1ca8e
# Step 6/14 : ARG PIP=pip3
#  ---> Using cache
#  ---> 216f47ffc4c2
# Step 7/14 : WORKDIR /
#  ---> Using cache
#  ---> 39b1e3addfb7
# Step 8/14 : RUN ${PIP} install --no-cache --upgrade             pandas flask gunicorn             numpy==1.19.5             statsmodels             scikit-learn             xgboost             boto3             scipy
#  ---> Running in 9bb7b358ce6d
# Collecting pandas
#   Downloading pandas-1.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
# Collecting flask
#   Downloading Flask-2.0.2-py3-none-any.whl (95 kB)
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5-cp38-cp38-manylinux2010_x86_64.whl (14.9 MB)
# Collecting statsmodels
#   Downloading statsmodels-0.13.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Collecting xgboost
#   Downloading xgboost-1.5.2-py3-none-manylinux2014_x86_64.whl (173.6 MB)
# Collecting boto3
#   Downloading boto3-1.20.46-py3-none-any.whl (131 kB)
# Collecting scipy
#   Downloading scipy-1.7.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.3 MB)
# Collecting python-dateutil>=2.8.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Collecting click>=7.1.2
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Requirement already satisfied, skipping upgrade: setuptools>=3.0 in /usr/lib/python3/dist-packages (from gunicorn) (45.2.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
# Collecting botocore<1.24.0,>=1.23.46
#   Downloading botocore-1.23.46-py3-none-any.whl (8.5 MB)
# Collecting six>=1.5
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp38-cp38-manylinux2010_x86_64.whl (30 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
# Installing collected packages: numpy, six, python-dateutil, pytz, pandas, click, itsdangerous, Werkzeug, MarkupSafe, Jinja2, flask, gunicorn, scipy, patsy, statsmodels, threadpoolctl, joblib, scikit-learn, xgboost, jmespath, urllib3, botocore, s3transfer, boto3
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 Werkzeug-2.0.2 boto3-1.20.46 botocore-1.23.46 click-8.0.3 flask-2.0.2 gunicorn-20.1.0 itsdangerous-2.0.1 jmespath-0.10.0 joblib-1.1.0 numpy-1.19.5 pandas-1.4.0 patsy-0.5.2 python-dateutil-2.8.2 pytz-2021.3 s3transfer-0.5.0 scikit-learn-1.0.2 scipy-1.7.3 six-1.16.0 statsmodels-0.13.1 threadpoolctl-3.1.0 urllib3-1.26.8 xgboost-1.5.2
# Removing intermediate container 9bb7b358ce6d
#  ---> 54c5f77a8e8f
# Step 9/14 : ENV PYTHONDONTWRITEBYTECODE=1     PYTHONUNBUFFERED=1     LD_LIBRARY_PATH="${LD_LIBRARY_PATH}:/usr/local/lib"     PYTHONIOENCODING=UTF-8     LANG=C.UTF-8     LC_ALL=C.UTF-8
#  ---> Running in d25b02688053
# Removing intermediate container d25b02688053
#  ---> 52c9d692f201
# Step 10/14 : RUN ${PIP} install --no-cache --upgrade     multi-model-server sagemaker-inference
#  ---> Running in 6cb74866cd5a
# Collecting multi-model-server
#   Downloading multi_model_server-1.1.8-py2.py3-none-any.whl (6.4 MB)
# Collecting sagemaker-inference
#   Downloading sagemaker_inference-1.5.10.tar.gz (21 kB)
# Collecting psutil
#   Downloading psutil-5.9.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Collecting Pillow
#   Downloading Pillow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# Collecting model-archiver
#   Downloading model_archiver-1.0.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.8/dist-packages (from sagemaker-inference) (1.19.5)
# Collecting retrying==1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.8/dist-packages (from sagemaker-inference) (1.7.3)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.8/dist-packages (from sagemaker-inference) (1.16.0)
# Collecting enum-compat
#   Downloading enum_compat-0.0.3-py3-none-any.whl (1.3 kB)
# Building wheels for collected packages: sagemaker-inference, future, retrying
#   Building wheel for sagemaker-inference (setup.py): started
#   Building wheel for sagemaker-inference (setup.py): finished with status 'done'
#   Created wheel for sagemaker-inference: filename=sagemaker_inference-1.5.10-py2.py3-none-any.whl size=27596 sha256=9746bcebee95cea319683d427b4112db15bd5fe670b36cf32cc3ea3e2ab68860
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5a5uq0vn/wheels/98/f4/b3/587ac05446d1366f38f7d96a6187b77b20861137c26176961b
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=683e6d38197e0c76285ed9f441e85b34f56d3a1372839e240cbecb94c34b86c9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5a5uq0vn/wheels/8e/70/28/3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11430 sha256=a42a1b44df171a52f0bf0dfbdef71899f0d792150ae4723627c1b68918216e2f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5a5uq0vn/wheels/c4/a7/48/0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built sagemaker-inference future retrying
# Installing collected packages: psutil, future, Pillow, enum-compat, model-archiver, multi-model-server, retrying, sagemaker-inference
# Successfully installed Pillow-9.0.0 enum-compat-0.0.3 future-0.18.2 model-archiver-1.0.3 multi-model-server-1.1.8 psutil-5.9.0 retrying-1.3.3 sagemaker-inference-1.5.10
# Removing intermediate container 6cb74866cd5a
#  ---> 0f072a149d7a
# Step 11/14 : COPY model/* /opt/ml/code/
#  ---> ba64b6552bc6
# Step 12/14 : WORKDIR /opt/ml/code
#  ---> Running in 2e4919d90096
# Removing intermediate container 2e4919d90096
#  ---> 98aa6a6e60b5
# Step 13/14 : RUN chmod +x /opt/ml/code/serve.py
#  ---> Running in 169393c1a913
# Removing intermediate container 169393c1a913
#  ---> 7c171c09825a
# Step 14/14 : ENTRYPOINT ["python3", "/opt/ml/code/serve.py"]
#  ---> Running in c6a511a02571
# Removing intermediate container c6a511a02571
#  ---> 4c198312799d
# Successfully built 4c198312799d
# Successfully tagged customer-churn-inference-image:latest
# The push refers to repository [120582440665.dkr.ecr.ap-southeast-1.amazonaws.com/customer-churn-inference-image]
# de58e73d7eaf: Preparing
# 59706bff4240: Preparing
# 37667a2e5c7d: Preparing
# 474cea0a1c60: Preparing
# ddc51a692431: Preparing
# fdbaa48b759b: Preparing
# 491a2ee5fddd: Preparing
# 0eba131dffd0: Preparing
# fdbaa48b759b: Waiting
# 491a2ee5fddd: Waiting
# 0eba131dffd0: Waiting
# 59706bff4240: Pushed
# de58e73d7eaf: Pushed
# 37667a2e5c7d: Pushed
# ddc51a692431: Pushed
# 491a2ee5fddd: Pushed
# 0eba131dffd0: Pushed
# fdbaa48b759b: Pushed
# 474cea0a1c60: Pushed
# latest: digest: sha256:506bfbe11097ec6b7a2b2fdc9dcc46e5cd33822811dc77d4639609bac0b5154f size: 2006
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store

# %% [markdown]
# ## Docker Deployment for
# #### Pipeline segment: **Evaluation**
# ---

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.estimator import Estimator
from sagemaker.debugger import rule_configs, Rule, DebuggerHookConfig, CollectionConfig

# %%
import boto3

account_id = boto3.client('sts').get_caller_identity().get('Account')
region = boto3.Session().region_name
ecr_repository = 'dl-viu-recommendation-evaluation'
tag = ':latest'
processing_repository_uri = '{}.dkr.ecr.{}.amazonaws.com/{}'.format(account_id, region, ecr_repository + tag)

# Create ECR repository and push docker image
# !docker build -t $ecr_repository docker
# !aws ecr get-login-password --region {region} | docker login --username AWS --password-stdin {account_id}.dkr.ecr.{region}.amazonaws.com
# !aws ecr create-repository --repository-name $ecr_repository
# !docker tag {ecr_repository + tag} $processing_repository_uri
# !docker push $processing_repository_uri

# %%
# %%bash
#
# image=dl-viu-recommendation-evaluation
#
# cd evaluation_container
#
# chmod +x recsys_evaluation/
#
# # Get the account number associated with the current IAM credentials
# account=$(aws sts get-caller-identity --query Account --output text)
#
# if [ $? -ne 0 ]
# then
#     exit 255
# fi
#
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# #region=${region:-us-west-1}
#
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image}:latest"
#
# # If the repository doesn't exist in ECR, create it.
#
# aws ecr describe-repositories --repository-names "${image}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${image}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# aws ecr get-login-password --region "${region}" | docker login --username AWS --password-stdin "${account}".dkr.ecr."${region}".amazonaws.com
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
#
# docker build  -t ${image} .
# docker tag ${image} ${fullname}
#
# docker push ${fullname}

# %%
eval_image_uri = '{}.dkr.ecr.{}.{}/{}'.format(account_id, region, uri_suffix, ecr_repository + tag)

# eval_image_uri = "120582440665.dkr.ecr.ap-southeast-1.amazonaws.com/dl-viu-recommendation-training"
eval_image_uri

# %%
from sagemaker.processing import ScriptProcessor, ProcessingInput, ProcessingOutput

script_processor = ScriptProcessor(command=['python3'],
                image_uri=eval_image_uri,
                role=get_execution_role(),
                instance_count=1,
                instance_type='ml.m5.xlarge')

# %%
script_processor.run(
    code="evaluation_container/recsys_evaluation/evaluator.py",
    arguments=["--env", "dev"],
)
